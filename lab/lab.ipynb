import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from bs4 import BeautifulSoup as soup # HTML parser
import requests # Page requests
import re # Regular expressions

print("requesting url...")
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0'} # How we wish to appear to CL
url = 'https://charlottesville.craigslist.org/search/msa?purveyor=owner#search=2~gallery~0'
raw = requests.get(url,headers=header) # Get page
print("done")

print("parsing html")
bsObj = soup(raw.content,'html.parser') # Parse the html
listings = bsObj.find_all(class_="cl-static-search-result") # Find all listings of the kind we want
print("done")

instrument_types = ['organ', 'piano', 'flute', 'guitar', 'amplifier', 'bass', 'trumpet', 'trombone', 'tuba', 'saxophone', 'drum']

print("collecting data")
data = [] # We'll save our listings in this object
for k in range( len(listings) ):
    title = listings[k].find('div',class_='title').get_text().lower()
    price = listings[k].find('div',class_='price').get_text()
    link = listings[k].find(href=True)['href']
    # Get brand from the title string:
    words = title.split()
    hits = [word for word in words if word in instrument_types] # Find brands in the title
    if len(hits) == 0:
        instrument = 'unknown'
    else:
        instrument = hits[0]
    # Get years from title string:
    regex_search = re.search(r'20[0-9][0-9]|19[0-9][0-9]', title ) # Find year references
    if regex_search is None: # If no hits, record year as missing value
        year = np.nan
    else: # If hits, record year as first match
        year = regex_search.group(0)
    #
    data.append({'title':title,'price':price,'year':year,'link':link,'instrument':instrument})

# Wrangling
df = pd.DataFrame.from_dict(data)
df['price'] = df['price'].str.replace('$','')
df['price'] = df['price'].str.replace(',','')
df['price'] = pd.to_numeric(df['price'],errors='coerce')
df['year'] = pd.to_numeric(df['year'],errors='coerce')
df['age'] = 2025-df['year']
print(df.shape)
df.to_csv('cl_instruments.csv')
df.head()

# Some basic analysis

print(df['price'].describe())
sns.boxplot(y=df['price'])
plt.show()

print(df['age'].describe())
df['age'].hist(bins=20)
plt.show()

# examine the data

ax = sns.scatterplot(data=df, x='age', y='price',hue='instrument')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))
plt.show()

# This scatterplot is showing a lot less data than I thought should be there


# Let me see if its getting compressed and try the arcsin (since I have zero value prices)
df['arc_price'] = np.arcsinh(df['price'])
df['arc_age'] = np.arcsinh(df['age'])

ax = sns.scatterplot(data=df, x='arc_age', y='arc_price',hue='instrument')
sns.move_legend(ax, "upper left", bbox_to_anchor=(1, 1))

print(df.loc[:,['arc_price','arc_age']].cov())
print(df.loc[:,['arc_price','arc_age']].corr())

# Nope that wasn't it
print(df['age'].value_counts().sum()) # Here it is, there's only 16 rows in the data that have an age recorded
# So I'm going to try and visualize how average price breaks down per instrument category
print(df['instrument'].value_counts())
print(df.loc[:,['price','instrument']].groupby('instrument').describe())

avg_price = df.groupby('instrument', as_index=False)['price'].mean().sort_values(by='price')
print(avg_price)

plt.clf()
sns.barplot(data=avg_price, x='instrument', y='price')
# This last bar chart gives some pretty good foundations for telling the story: "Pianos are the most expensive instrument on craigslist"
# Out:
# started
# requesting url...
# done
# parsing html
# done
# collecting data
# (126, 6)
# count     126.000000
# mean      579.801587
# std      1058.431693
# min         0.000000
# 25%       100.000000
# 50%       285.000000
# 75%       618.750000
# max      8950.000000
# Name: price, dtype: float64
# count    16.000000
# mean     30.562500
# std      21.354059
# min       1.000000
# 25%      11.750000
# 50%      34.500000
# 75%      46.500000
# max      65.000000
# Name: age, dtype: float64
#            arc_price   arc_age
# arc_price   3.543245  0.240498
# arc_age     0.240498  1.750556
#            arc_price   arc_age
# arc_price   1.000000  0.193582
# arc_age     0.193582  1.000000
# 16
# instrument
# unknown     90
# guitar      15
# piano        8
# bass         6
# drum         4
# organ        1
# flute        1
# trombone     1
# Name: count, dtype: int64
#            price                                                          \
#            count         mean          std    min     25%    50%     75%
# instrument
# bass         6.0   302.333333   247.080284   24.0  130.00  250.0   512.5
# drum         4.0   562.500000   330.088372  200.0  425.00  525.0   662.5
# flute        1.0    10.000000          NaN   10.0   10.00   10.0    10.0
# guitar      15.0   353.600000   314.680745    0.0   57.50  350.0   525.0
# organ        1.0   250.000000          NaN  250.0  250.00  250.0   250.0
# piano        8.0  2175.000000  3373.151346    0.0  198.75  452.5  2387.5
# trombone     1.0   175.000000          NaN  175.0  175.00  175.0   175.0
# unknown     90.0   509.466667   633.686950    0.0  100.00  295.0   687.5
#
#
#                max
# instrument
# bass         600.0
# drum        1000.0
# flute         10.0
# guitar      1000.0
# organ        250.0
# piano       8950.0
# trombone     175.0
# unknown     3000.0
#   instrument        price
# 2      flute    10.000000
# 6   trombone   175.000000
# 4      organ   250.000000
# 0       bass   302.333333
# 3     guitar   353.600000
# 7    unknown   509.466667
# 1       drum   562.500000
# 5      piano  2175.000000
# <Axes: xlabel='instrument', ylabel='price'>
